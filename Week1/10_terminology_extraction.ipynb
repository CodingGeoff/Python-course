# %% [markdown]
# # 🚀 术语提取 (Terminology Extraction)
#
# **代码融合了三种核心算法来挖掘高质量术语：**
# 1.  **spaCy (Linguistic):** 利用句法依赖分析提取名词短语 (Noun Chunks)。
# 2.  **NLTK (Statistical):** 利用互信息 (PMI) 提取高频双词搭配 (Bigram Collocations)。
# 3.  **TF-IDF (Weighting):** 计算术语在文档中的独特性权重，过滤通用词汇。
#
# ---

# %%
# === Cell 1: 环境检查与依赖安装 ===
import sys
import os
import pandas

# 1. 取消行数限制（显示所有行）
pd.set_option('display.max_rows', None)  
# 2. 取消列数限制（显示所有列）
pd.set_option('display.max_columns', None)  
# 3. 调整列宽（避免列内容被截断，设置为100字符宽度）
pd.set_option('display.max_colwidth', 100)  
# 4. 禁止列名换行（保持表格整洁）
pd.set_option('display.expand_frame_repr', False)

# 定义增强版依赖库
required_packages = [
    "pymupdf",       # PDF 解析
    "pytesseract",   # OCR
    "spacy",         # 语法分析
    "pandas",        # 数据处理
    "openpyxl",      # Excel 导出
    "requests",      # 网络请求
    "pillow",        # 图片处理
    "nltk",          # 自然语言处理 (搭配词提取)
    "scikit-learn"   # 机器学习 (TF-IDF 计算)
]

print("🛠️ 正在检查并安装缺失库...")
for package in required_packages:
    try:
        __import__(package)
    except ImportError:
        print(f"  ⬇️ 正在安装: {package}...")
        # !{sys.executable} -m pip install {package} -q

# 下载 NLP 模型数据
import spacy
import nltk

try:
    nlp = spacy.load("en_core_web_sm")
except OSError:
    print("  ⬇️ 下载 spaCy 模型...")
    # !{sys.executable} -m spacy download en_core_web_sm
    nlp = spacy.load("en_core_web_sm")

print("  ⬇️ 检查 NLTK 数据包...")
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)

print("✅ 所有环境配置就绪！")
# Out:
# 🛠️ 正在检查并安装缺失库...
#   ⬇️ 正在安装: pillow...
#   ⬇️ 正在安装: scikit-learn...
#   ⬇️ 检查 NLTK 数据包...
# ✅ 所有环境配置就绪！

# %%
# === Cell 2: 智能 PDF 解析器 (支持分页处理) ===
import fitz  # PyMuPDF
import pytesseract
from PIL import Image
import io
import requests

# 设置 Tesseract 路径 (Windows用户需根据实际情况修改)
# 如果在 Mac/Linux 上通常不需要这行，或者路径不同
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
if not os.path.exists(pytesseract.pytesseract.tesseract_cmd):
    # 备用路径尝试
    pytesseract.pytesseract.tesseract_cmd = r'd:\Tesseract-OCR\tesseract.exe'

def download_sample_pdf(url, filename="sample_paper.pdf"):
    if os.path.exists(filename):
        print(f"📂 使用本地文件: {filename}")
        return filename
    print(f"⬇️ 正在下载: {url}...")
    try:
        response = requests.get(url, stream=True)
        with open(filename, 'wb') as f:
            f.write(response.content)
        return filename
    except Exception as e:
        print(f"❌ 下载失败: {e}")
        return None

def parse_pdf_by_pages(pdf_path):
    """
    解析 PDF 并返回一个列表，列表每项代表一页的文本。
    这对于 TF-IDF 很重要，因为我们需要区分文档的不同部分。
    """
    if not pdf_path: return []
    
    doc = fitz.open(pdf_path)
    pages_content = []
    print(f"🚀 开始解析 PDF (共 {len(doc)} 页)...")

    for i, page in enumerate(doc):
        text = page.get_text()
        
        # 简单的扫描件检测
        if len(text.strip()) < 50:
            print(f"  ⚠️ 第 {i+1} 页疑似扫描件，尝试 OCR...")
            try:
                pix = page.get_pixmap(matrix=fitz.Matrix(2, 2))
                img = Image.open(io.BytesIO(pix.tobytes("png")))
                text = pytesseract.image_to_string(img, lang='eng')
            except:
                text = "" # OCR 失败忽略
        
        # 清洗基础格式
        text = text.replace('\n', ' ').strip()
        pages_content.append(text)
        
    return pages_content

# 准备数据
pdf_url = "https://arxiv.org/pdf/1706.03762.pdf" # Attention Is All You Need
local_pdf = download_sample_pdf(pdf_url, "paper.pdf")
raw_pages = parse_pdf_by_pages(local_pdf)
print(f"✅ 解析完成，获取 {len(raw_pages)} 页内容。")
# Out:
# 📂 使用本地文件: paper.pdf
# 🚀 开始解析 PDF (共 25 页)...
#   ⚠️ 第 19 页疑似扫描件，尝试 OCR...
#   ⚠️ 第 20 页疑似扫描件，尝试 OCR...
#   ⚠️ 第 21 页疑似扫描件，尝试 OCR...
#   ⚠️ 第 22 页疑似扫描件，尝试 OCR...
#   ⚠️ 第 23 页疑似扫描件，尝试 OCR...
#   ⚠️ 第 24 页疑似扫描件，尝试 OCR...
#   ⚠️ 第 25 页疑似扫描件，尝试 OCR...
# ✅ 解析完成，获取 25 页内容。

# %%
# === Cell 3: 核心算法融合 (TF-IDF + spaCy + NLTK) ===
import pandas as pd
import re
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.collocations import BigramCollocationFinder, BigramAssocMeasures
from nltk.corpus import stopwords

class TerminologyExtractor:
    def __init__(self, nlp_model):
        self.nlp = nlp_model
        self.stop_words = set(stopwords.words('english'))
        # 添加一些学术论文特有的无效词
        self.stop_words.update(['et', 'al', 'figure', 'table', 'section', 'fig', 'eq', 'p.', 'pp.', 'doi'])

    def preprocess(self, text):
        # 移除引用 [1], 标点等
        text = re.sub(r'\[\d+\]', '', text)
        text = re.sub(r'[^a-zA-Z\s-]', '', text) # 仅保留字母和连字符
        return text

    def get_spacy_candidates(self, text):
        """使用 spaCy 提取名词短语 (Noun Chunks)"""
        doc = self.nlp(text[:1000000]) # 限制长度防止内存溢出
        candidates = []
        for chunk in doc.noun_chunks:
            term = chunk.text.lower().strip()
            # 过滤规则：长度>2，不含数字，不在停用词表中
            if len(term) > 2 and term not in self.stop_words:
                # 进阶过滤：只保留包含空格的词组 (single word 往往太通用)
                if " " in term:
                    candidates.append(term)
        return candidates

    def get_nltk_collocations(self, text, top_n=100):
        """使用 NLTK 提取高频搭配 (Bigrams)"""
        tokens = nltk.word_tokenize(text.lower())
        # 仅保留纯字母词
        tokens = [w for w in tokens if w.isalpha() and w not in self.stop_words]
        
        bigram_measures = BigramAssocMeasures()
        finder = BigramCollocationFinder.from_words(tokens)
        # 过滤掉出现少于 3 次的搭配
        finder.apply_freq_filter(3)
        
        # 返回前 Top N 的搭配词 (按频率)
        return [' '.join(bigram) for bigram in finder.nbest(bigram_measures.raw_freq, top_n)]

    def calculate_tfidf_scores(self, pages_list, candidates):
        """计算候选词的 TF-IDF 分数"""
        # 仅针对我们要分析的候选词建立词汇表
        vocab = list(set(candidates))
        if not vocab: return {}
        
        # TF-IDF 设置：ngram范围1-3，使用自定义词汇表
        vectorizer = TfidfVectorizer(
            vocabulary=vocab, 
            ngram_range=(1, 3), 
            stop_words='english',
            norm='l2'
        )
        
        try:
            tfidf_matrix = vectorizer.fit_transform(pages_list)
            # 对所有页面的分数求和或取平均，代表该词在全文的重要性
            feature_names = vectorizer.get_feature_names_out()
            # Sum along columns (pages)
            scores = tfidf_matrix.sum(axis=0).A1 
            return dict(zip(feature_names, scores))
        except ValueError:
            return {}

    def find_context(self, term, full_text):
        """查找例句"""
        start = full_text.find(term)
        if start != -1:
            # 截取前后 50 个字符
            s = max(0, start - 50)
            e = min(len(full_text), start + len(term) + 50)
            return "..." + full_text[s:e].replace('\n', ' ') + "..."
        return ""

    def process(self, pages_content):
        full_text = " ".join(pages_content)
        clean_text = self.preprocess(full_text)
        
        print("1️⃣ 正在运行 spaCy 句法提取...")
        spacy_terms = self.get_spacy_candidates(clean_text)
        
        print("2️⃣ 正在运行 NLTK 搭配分析...")
        nltk_terms = self.get_nltk_collocations(clean_text)
        
        # 合并候选集 (去重)
        all_candidates = list(set(spacy_terms + nltk_terms))
        print(f"   - 提取到 {len(all_candidates)} 个唯一候选术语")
        
        print("3️⃣ 正在计算 TF-IDF 权重...")
        tfidf_scores = self.calculate_tfidf_scores(pages_content, all_candidates)
        
        # 统计原始频率
        freq_counts = Counter(spacy_terms + nltk_terms) # 这里简化统计，实际应在原问中统计
        # 更精准的频率统计：在原清洗文本中统计
        final_stats = []
        
        print("4️⃣ 正在整合与评分...")
        for term in all_candidates:
            count = full_text.lower().count(term)
            if count < 2: continue # 过滤低频孤例
            
            tfidf = tfidf_scores.get(term, 0)
            
            # === 评分公式 ===
            # 综合分 = Log(频率) * TF-IDF + 来源加权
            # 如果是 spaCy (语法正确) 且是 NLTK (统计显著)，加分
            is_spacy = 1 if term in spacy_terms else 0
            is_nltk = 1 if term in nltk_terms else 0
            
            composite_score = (tfidf * 10) * (1 + (is_spacy * 0.2) + (is_nltk * 0.2))
            
            final_stats.append({
                "Term": term,
                "Frequency": count,
                "TF-IDF Score": round(tfidf, 4),
                "Composite Score": round(composite_score, 4),
                "Source": "Both" if is_spacy and is_nltk else ("spaCy" if is_spacy else "NLTK"),
                "Context": self.find_context(term, full_text)
            })
            
        df = pd.DataFrame(final_stats)
        return df.sort_values(by="Composite Score", ascending=False)

# 实例化并运行
extractor = TerminologyExtractor(nlp)
df_final = extractor.process(raw_pages)

# 显示前 150 个高质量术语
display(df_final.head(150))
# Out:
# 1️⃣ 正在运行 spaCy 句法提取...
# 2️⃣ 正在运行 NLTK 搭配分析...
#    - 提取到 1333 个唯一候选术语
# 3️⃣ 正在计算 TF-IDF 权重...
# 4️⃣ 正在整合与评分...
#                              Term  Frequency  TF-IDF Score  Composite Score Source                                                                                              Context
# 165                 opioid misuse         50        2.4244          33.9409   Both  ...10-z A videogame for perceived risk of harm from  opioid misuse in adolescents: a randomized ...
# 71                 perceived risk         33        1.6959          23.7420   Both  ...oi.org/10.1038/s44360-025-00010-z A videogame for perceived risk of harm from  opioid misuse ...
# 65                  nature health         21        1.3833          19.3667   Both  ...ature Health | Volume 1 | January 2026 | 78–89 78 nature health Article https://doi.org/10.10...
# 59                     great risk         29        1.3237          18.5316   Both  ...art versus 23% of control participants reported  ‘great risk’ with no statistically significa...
# 58                          et al         28        1.4672          17.6064  spaCy  ... Of the 1,062 unique indi- viduals screened, 839 met all inclusion criteria and 533 enroled: ...
# 163                 extended data         12        1.3587          16.3047   NLTK
# 178           extended data table         12        1.3587          16.3047  spaCy
# 17                 health article          7        1.2976          15.5710   NLTK
# 141           randomization group         15        1.0771          15.0789   Both  ...sing a linear mixed model with  fixed effects for randomization group, time, interaction of r...
# 174                 substance use         17        0.9506          13.3086   Both  ... no prior opioid misuse and  ‘high-risk’ based on substance use or mental health screens—agre...
# 34             secondary outcomes          9        0.8508          11.9106   Both  ...d risk of harm  of opioid misuse at 3 months. The secondary outcomes were self-efficacy,  int...
# 117         negative expectancies         13        0.8462          11.8472   Both  ...intentions, knowledge and attitudes (positive and negative expectancies).   At 3 months, 29% ...
# 14               controlled trial         10        0.8209          11.4921   Both  ...from  opioid misuse in adolescents: a randomized  controlled trial   Tyra Boomer    1,2  , Li...
# 5             prescription opioid         18        0.9136          10.9633   NLTK  ...  Initiation of opioid misuse (non-medical use of prescription opioids/ prescription opioid m...
# 16          randomized controlled          9        0.8628          10.3537   NLTK  ...8 years45. Through a two-arm parallel superiority randomized controlled  trial, we evaluated ...
# 72     prescription opioid misuse         11        0.8507          10.2081  spaCy  ... misuse (non-medical use of prescription opioids/ prescription opioid misuse and/or heroin us...
# 154                control groups          4        0.6739           9.4343   Both  ...ions to misuse opioids between  the PlaySmart and control groups (Fig. 3b). At 6 weeks, the m...
# 19                     heroin use          8        0.6672           9.3404   Both  ...iption opioids/ prescription opioid misuse and/or heroin use) often occurs in ado- lescence a...
# 194          great perceived risk          3        0.6855           8.2260  spaCy  ... Opioids (B) Prevalence of adolescents reporting ‘great perceived risk of harm’ from heroin (...
# 31                       drug use         14        0.5671           7.9399   Both  ...hood. Recent data indicate that although  illicit drug use among youth is decreasing, fatal o...
# 168                 fixed effects          5        0.5548           7.7672   Both  ...s were generated using a linear mixed model with  fixed effects for randomization group, time...
# 199                 control group         15        0.6411           7.6930   NLTK  ...) of the PlaySmart group and 17% (46/263) of  the control group reported ‘great risk of harm’...
# 82                playsmart group         12        0.6341           7.6097   NLTK
# 129         positive expectancies          6        0.5117           7.1640   Both  ... to 14%; P = 0.14). Self-efficacy, intentions and positive expectancies  did not differ. Play...
# 211             baseline baseline          4        0.5762           6.9139   NLTK
# 106              months playsmart          2        0.5727           6.8722   NLTK
# 205          prescription opioids          6        0.4751           6.6516   Both  ...  Initiation of opioid misuse (non-medical use of prescription opioids/ prescription opioid m...
# 73                    mean scores          7        0.5279           6.3345   NLTK  ... −0.2 (95%  CI, −0.5–0.0; P = 0.39). At 3 months, mean scores were as follows:  PlaySmart = 9...
# 70                    high school          9        0.4405           6.1673   Both  ...week for approximately 6 weeks) at 15 Connecticut high schools. Self- reported data were coll...
# 104                  total number          4        0.5111           6.1331  spaCy
# 53                data collection          5        0.4140           5.7955   Both  ...collection and management REDCap P11 was used for data collection, management and monitoring,...
# 145              risk differences          2        0.4732           5.6782  spaCy
# 90                  mental health          6        0.3948           5.5267   Both  ...misuse and  ‘high-risk’ based on substance use or mental health screens—agreed to 60-min  gam...
# 169           competing interests          2        0.4601           5.5215  spaCy  ...cal Studies, YCAS). The other authors declare no  competing interests. Additional information...
# 110             systematic review          6        0.4282           5.1388   NLTK  ...ates schools to prevent opioid-related harms:   a systematic review. Addict. Behav. 163, 1082...
# 76                primary outcome          7        0.4224           5.0691   NLTK  ... (87%) PlaySmart  and 234/261 (90%) control). The primary outcome was perceived risk of harm ...
# 198                    mean score         13        0.4211           5.0528   NLTK  ... −0.2 (95%  CI, −0.5–0.0; P = 0.39). At 3 months, mean scores were as follows:  PlaySmart = 9...
# 26               group assignment          6        0.4211           5.0528   NLTK  ...e 6 weeks 3 months 80 100 PlaySmart Randomization group assignment Control Fig. 2 | Percent r...
# 153       playsmart randomization          6        0.4211           5.0528   NLTK
# 93                 misuse opioids          4        0.3578           5.0094   Both  ...0.98). There were no differences in intentions to misuse opioids between  the PlaySmart and c...
# 87               random intercept          5        0.4129           4.9553  spaCy  ...ORs and 95% CIs.  Additional adjusted models with random intercepts for participant and  part...
# 49                  maximum score          5        0.4103           4.9230   NLTK  ...stance Self-Efficacy (DURSE) scale61 (two items,  maximum score = 10). Higher scores indicate...
# 150          intervention control          2        0.4093           4.9111   NLTK
# 28                school students          8        0.3948           4.7376   NLTK  ...ear-olds3. In 2023, 12% (1.9 million) of US  high-school students reported lifetime prescript...
# 200               risk perception          7        0.3339           4.6746   Both  ... 0.11) (Extended Data Table 2B). Finally, because risk perception differs between heroin and ...
# 97                     harm scale          2        0.3885           4.6624  spaCy
# 142      opioid misuse prevention          5        0.3669           4.4024  spaCy  ...nce  PlaySmart, maximizing its impact on scalable opioid misuse prevention.  ClinicalTrials.g...
# 81              misuse prevention          5        0.3669           4.4024   NLTK  ...aySmart, maximizing its impact on scalable opioid misuse prevention.  ClinicalTrials.gov regi...
# 109                  young people          5        0.3137           4.3922   Both  ...the prevalence and lethality of opioid misuse  in young people, creating evidence-based scala...
# 50                    odds ratios          2        0.3651           4.3815  spaCy  ...bjects within schools. Odds ratios (OR), adjusted odds ratios (aOR), 95% confidence intervals...
# 1             reported initiation          2        0.3356           4.0273  spaCy  ...ion Opioid Misuse or Heroin Use Incidence of self-reported initiation of prescription opioid ...
# 0               contributing data          5        0.3343           4.0115   NLTK  ... at baseline, 6 weeks and 3 months.   The numbers contributing data for PlaySmart were 269, 2...
# 62             assignment control          5        0.3343           4.0115   NLTK
# 177          numbers contributing          5        0.3343           4.0115   NLTK  ...ed line) at baseline, 6 weeks and 3 months.   The numbers contributing data for PlaySmart wer...
# 156          high school students          3        0.3318           3.9814  spaCy  ...adshaw, C. P. Synthetic and other  drug use among high school students: The role of perceived...
# 45         playsmart participants          4        0.2780           3.8916   Both
# 112        videogame intervention          4        0.2946           3.5351   NLTK  ...T39, focused on opioid safety,  and our PlaySmart videogame intervention described here speci...
# 203              substance misuse          3        0.2704           3.2452  spaCy  ...) Prefer to not say 2 (1%) 1 (0%) 3 (1%) Familial substance misuseb (n, %) Father 29 (11%) 28...
# 84                   high schools          4        0.2691           3.2292  spaCy  ...week for approximately 6 weeks) at 15 Connecticut high schools. Self- reported data were coll...
# 127         digital interventions          5        0.2270           3.1784   Both  ...e impact of game- based learning and the value of digital interventions for reach and  scale....
# 167            study participants          2        0.2647           3.1767  spaCy  ...  in recruitment, data collection and guidance of study participants.  Finally, we acknowledg...
# 138                  control arms          3        0.2612           3.1350  spaCy  ... assessments for the PlaySmart (intervention) and control arms.  aReasons that eligible indiv...
# 187                    video game          6        0.2574           3.0891   NLTK  ..., Fernandes, C.-S.  F. & Fiellin, L. E. A serious video game targeting HIV testing and  couns...
# 201          intervention effects          2        0.2573           3.0872  spaCy  ...ted, we did  not examine potential differences in intervention effects by gender  due to smal...
# 107            school commitments          2        0.2555           3.0665  spaCy  ... issues after school, or other family, or work or school commitments after school.    Complet...
# 61           eligible individuals          2        0.2555           3.0665  spaCy  ... 3-month assessment:  231/266 (87%) aReasons that eligible individuals did not participate in...
# 57           screened individuals          2        0.2555           3.0665  spaCy  ...                          380     Total number of screened individuals who were ineligible   ...
# 176        principal investigator          2        0.2512           3.0147  spaCy  ...on. One control participant was withdrawn by the  principal investigator due to an incomplete...
# 85                 use prevention          9        0.2483           2.9801   NLTK  ...mart, maximizing its impact on scalable opioid misuse prevention.  ClinicalTrials.gov registr...
# 114                 actual misuse          3        0.2459           2.9511  spaCy  ...ficantly associated  with increased likelihood of actual misuse, underscoring the need for  i...
# 40    key behavioural antecedents          2        0.2431           2.9170  spaCy  ...ess, and  although we aimed to target a number of key behavioural antecedents,  such as findi...
# 15       baseline characteristics          4        0.2366           2.8389  spaCy  ..., resulting in a sample size of 532 (Fig. 1). The baseline characteristics were similar acros...
# 162           videogame playsmart          2        0.2219           2.6630   NLTK
# 122             random intercepts          3        0.2198           2.6377  spaCy  ...ORs and 95% CIs.  Additional adjusted models with random intercepts for participant and  part...
# 134                   sample size          4        0.2111           2.5326  spaCy  ...Institutional Review  Board (IRB), resulting in a sample size of 532 (Fig. 1). The baseline c...
# 184              parental consent          2        0.2068           2.4810  spaCy  ...0-min  gameplay sessions, and provided assent and parental consent if under 18 years  old. Pa...
# 47                  red triangles          3        0.2026           2.4312  spaCy  ...Smart (blue circles and solid line) and  control (red triangles and dashed line) at baseline,...
# 121              knowledge scores          3        0.2023           2.4278  spaCy  ... opioids (range 2–16) over time by group. c, Mean knowledge scores (range 0–38)  over time by...
# 39           adolescent substance          3        0.1982           2.3785   NLTK  ...al. Although there are interventions  that target adolescent substance use, including opioids...
# 25           control participants          2        0.1940           2.3281  spaCy  ...s).   At 3 months, 29% of PlaySmart versus 23% of control participants reported  ‘great risk’...
# 157             misuse initiation          3        0.1882           2.2581  spaCy  ... perceived risk of harm—an important predictor of misuse initiation. Here, to  address this, ...
# 155               similar changes          2        0.1861           2.2338  spaCy  ...I, 9.5–11.2; P = 0.80) being comparable, showing  similar changes from baseline to 6 weeks: P...
# 135                adverse events          3        0.1849           2.2184  spaCy  ...he game (73%, 165/227). Harms There were two mild adverse events reported, one at baseline an...
# 125              behaviour change          2        0.1802           2.1619  spaCy  ...rticle https://doi.org/10.1038/s44360-025-00010-z behaviour change theories and user-centred ...
# 158                   solid lines          2        0.1679           2.0149  spaCy  ...5% CIs presented for PlaySmart (blue  circles and solid lines) and control (red triangles and...
# 99             post randomization          3        0.1596           1.9152  spaCy  ...ificantly different between groups. At  3 months (post randomization), 29% (66/231) of the Pl...
# 22               illicit drug use          2        0.1543           1.8521  spaCy  ...ng adulthood. Recent data indicate that although  illicit drug use among youth is decreasing,...
# 102                 national data          2        0.1505           1.8055  spaCy  ...erceived risk of  harm from opioid misuse because national data on adolescents, and our  stud...
# 4                    higher score          3        0.1465           1.7585  spaCy  ...pioids were summed and ranged from 2 to  10, with higher score indicating greater self-effica...
# 21              additional models          2        0.1465           1.7585  spaCy
# 195       implementation fidelity          3        0.1430           1.7158  spaCy  ...imited funding, insufficient staff training,  low implementation fidelity, stigma, curriculum...
# 208               opioid toxicity          2        0.1427           1.7120  spaCy  ... risk among  adolescents has increased2. In 2021, opioid toxicity accounted for  over 10% of ...
# 160      connecticut high schools          2        0.1408           1.6901  spaCy
# 132      adolescent opioid misuse          2        0.1408           1.6901  spaCy  ...s is criti- cal. A potential target for impacting adolescent opioid misuse is their  perceive...
# 33            lifeskills training          2        0.1216           1.4591  spaCy
# 130           small subgroup size          2        0.1215           1.4585  spaCy  ...erences in intervention effects by gender  due to small subgroup sizes and the scope of the c...
# 123                  young adults          2        0.1109           1.3310  spaCy  ...of a computer game to promote a  healthy diet for young adults. Health Commun. 24, 115–127 (2...
# 51             prescription drugs          2        0.1109           1.3310  spaCy  ...as been demonstrated with the non-medical use of  prescription drugs6,9–12 and heroin13. Indi...
# 7         substance use disorders          2        0.1109           1.3310  spaCy  ...etti, J. & Ferrari, M. Digital interventions for  substance use disorders in young people: ra...
# 75                  marijuana use          2        0.1100           1.3198  spaCy  ...Humphrey, R.  H. Explaining the recent decline in marijuana use: differentiating  the effects...
# 44                    hiv testing          2        0.1100           1.3198  spaCy
# 183                 opioid safety          2        0.1082           1.2979  spaCy  ... formative efforts such as MedSMA℞T39, focused on opioid safety,  and our PlaySmart videogame...
# 56       opioid misuse initiation          2        0.1068           1.2817  spaCy  ...enting effective, engaging strategies to prevent  opioid misuse initiation is critical. Altho...
# 66       adolescent substance use          2        0.0965           1.1578  spaCy  ...al. Although there are interventions  that target adolescent substance use, including opioids...
# 164                    solid line          3        0.0620           0.7446  spaCy  ...opioids presented for PlaySmart (blue circles and solid line) and  control (red triangles and...
# 206                     juana use          3        0.0534           0.6408  spaCy  .... Participants reported lifetime alcohol or mari- juana use (33% (175/532) and 19% (102/532))...
# 83                       redcap p          2        0.0000           0.0000  spaCy
# 69                   a great risk          3        0.0000           0.0000  spaCy  ...trying a prescription opioid once or twice  posed a great risk of harm, and only 34% of 12th ...
# 68              the current study          2        0.0000           0.0000  spaCy  ...tion- ally consistent with the 6-week findings in the current study—26% of  PlaySmart versus ...
# 64                 the manuscript          3        0.0000           0.0000  spaCy  ...esults.  T.B. and L.E.F. wrote the first draft of the manuscript. T.B., L.E.F., L.H.,  K.L., ...
# 78            least squared means          2        0.0000           0.0000  spaCy  ...cores were compared between the  two groups using least squared means using a mixed-effects m...
# 79           high-school students          3        0.0000           0.0000  spaCy  ...–19-year-olds3. In 2023, 12% (1.9 million) of US  high-school students reported lifetime pres...
# 80              their interaction          2        0.0000           0.0000  spaCy  ...fixed  effects for randomization group, time, and their interaction, with a random intercept ...
# 77                        a proxy          2        0.0000           0.0000  spaCy  ...tion, perceptions of  use being ‘very dangerous’ (a proxy for ‘great risk of harm’) increased...
# 74           a systematic  review          3        0.0000           0.0000  spaCy  ...z, M. et al. Winning the game against depression: a systematic  review of video games for the...
# 18                     the impact          5        0.0000           0.0000  spaCy  ...iority randomized controlled  trial, we evaluated the impact of PlaySmart, compared to a plac...
# 20                    no gameplay          2        0.0000           0.0000  spaCy
# 12            the primary outcome          4        0.0000           0.0000  spaCy  ...nificant difference in perceived  risk of harm at the primary outcome timepoint of 3 months. ...
# 11                           a co         18        0.0000           0.0000  spaCy  ...n, were deemed  possibly related to the study. Data completeness Completeness of assessments ...
# 10                       the risk          2        0.0000           0.0000  spaCy  ...ura, L. E. & Martins, S. S.  Joint perceptions of the risk and availability of cannabis in th...
# 9             to severe  symptoms          2        0.0000           0.0000  spaCy  ...y-five percent (238/532) of participants had mild to severe  symptoms of anxiety47, with 86% ...
# 8              up to six sessions          2        0.0000           0.0000  spaCy  ...Not willing to sit for 60 min per session    (for up to six sessions for each) to play a vide...
# 2                    the analysis          2        0.0000           0.0000  spaCy  ... the study design, but gender was not included in the analysis due to  small subgroup size. A...
# 3       all eligibility questions          2        0.0000           0.0000  spaCy  ...ach) to play a videogame (15, 4%).  Data missing: all eligibility questions missing (5, 1%). ...
# 6                       the study         12        0.0000           0.0000  spaCy  ... that eligible individuals did not participate in the study included not returning the  enrol...
# 13                        total n          4        0.0000           0.0000  spaCy
# 60                 each timepoint          4        0.0000           0.0000  spaCy  ...ig. 2 | Percent reporting ‘great risk of harm’ at each timepoint, by treatment.  Percent repo...
# 54                  no great risk          4        0.0000           0.0000  spaCy  ...6% (36/231) of the PlaySmart  group shifted from ‘no great risk of harm’ at baseline to ‘grea...
# 55                         the us          4        0.0000           0.0000  spaCy  ...er, C., Tierney, K. & Birstler, J.  Investigating the use of a serious game to improve opioid...
# 67                the mean scores          4        0.0000           0.0000  spaCy  ...aySmart and control groups (Fig. 3b). At 6 weeks, the mean scores  were as follows: PlaySmart...
# 63                 self- efficacy          2        0.0000           0.0000  spaCy  ...mes (Figs. 3 and 4), there were no differences in self- efficacy to refuse opioids between gr...
# 48                   the findings          2        0.0000           0.0000  spaCy  .... Although opioids  were not assessed in ref. 52, the findings for marijuana are direction- a...
# 52                 each follow-up          2        0.0000           0.0000  spaCy  ...orted. Sub-table B shows changes from baseline to each follow-up  adjusted for baseline binar...
# 36           a placebo comparator          2        0.0000           0.0000  spaCy  ...ority unblinded randomized  controlled trial with a placebo comparator. We randomized 532 par...
# 35                  both baseline          2        0.0000           0.0000  spaCy  ...2–14%; P = 0.14). Among participants assessed  at both baseline and 3 months (N = 465), 16% (...
# 30                      the trial          2        0.0000           0.0000  spaCy  ...ng. Author contributions L.E.F. and T.B. designed the trial, and L.E.F. received funding for ...
# 32                  the questions          3        0.0000           0.0000  spaCy  ...e- scription opioids, we also separately analysed the questions related to  each substance49 ...
# 29    school-based harm reduction          2        0.0000           0.0000  spaCy  ...riers. For exam- ple, a recent study evaluating a school-based harm reduction pro- gramme for...
# 23                       the need          3        0.0000           0.0000  spaCy  ...creased likelihood of actual misuse, underscoring the need for  interventions that effectivel...
# 24              the effectiveness          3        0.0000           0.0000  spaCy
# 27                  a sample size          2        0.0000           0.0000  spaCy  ...e Institutional Review  Board (IRB), resulting in a sample size of 532 (Fig. 1). The baseline...
# 43                   the efficacy          2        0.0000           0.0000  spaCy  ...with our  previous research and that of others on the efficacy of serious games  in enhancing...
# 42              this relationship          2        0.0000           0.0000  spaCy  .... We anticipate being better  able to demonstrate this relationship with longer-term outcomes...
# 41                 the perception          2        0.0000           0.0000  spaCy
# 37              among adolescents          5        0.0000           0.0000   NLTK  ...pioid misuse. Given the magnitude of this problem among adolescents, devel- oping and impleme...
# 38   randomized  controlled trial          2        0.0000           0.0000  spaCy  ...isk of harm from  opioid misuse in adolescents: a randomized  controlled trial   Tyra Boomer ...
# 46         the national institute          2        0.0000           0.0000  spaCy
# 88           the playsmart  group          2        0.0000           0.0000  spaCy
# 100      mild to severe  symptoms          2        0.0000           0.0000  spaCy  ... Forty-five percent (238/532) of participants had mild to severe  symptoms of anxiety47, with...
# 148                the prevention          3        0.0000           0.0000  spaCy  ... including  serious games have been developed for the prevention of adolescent  alcohol, toba...

# %%
# === Cell 4: 结果美化与导出 ===

# 过滤掉太短的术语或纯数字噪音
filtered_df = df_final[df_final['Term'].str.len() > 4].copy()

# 重命名列以便阅读
export_columns = {
    "Term": "术语 (English)",
    "Frequency": "出现频次",
    "Composite Score": "相关性评分",
    "Source": "提取来源",
    "Context": "原文例句"
}
export_df = filtered_df.rename(columns=export_columns)

# 添加一列空白的中文翻译列
export_df.insert(1, "中文翻译", "")

filename = "Smart_Glossary_TFIDF.xlsx"
try:
    export_df.to_excel(filename, index=False)
    print(f"🎉 处理完毕！高质量术语表已保存至: {filename}")
    print(f"📊 共提取术语: {len(export_df)} 个")
except Exception as e:
    print(f"❌ 保存失败: {e}")
# Out:
# 🎉 处理完毕！高质量术语表已保存至: Smart_Glossary_TFIDF.xlsx
# 📊 共提取术语: 212 个
